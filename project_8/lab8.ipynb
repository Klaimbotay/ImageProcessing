# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img1 = cv2.imread(r'images/shablon.jpg', 0) # queryImage
img2 = cv2.imread(r'images/image.jpg', 0) # trainImage
sift = cv2.xfeatures2d.SIFT_create() # Initiate SIFT detector
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
bf = cv2.BFMatcher() # BFMatcher with default params
matches = bf.knnMatch(des1,des2, k=2)
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
# cv2.drawMatchesKnn expects list of lists as matches.
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2, matches1to2=good,
outImg=None, flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f6a80af32e8>, None)

# %%
img = cv2.imread('images/image.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)
# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
cv2.imwrite('images/image_H.jpg', img)
# Out:
# True

# %% [markdown]
# ![image_H.jpg](attachment:image_H.jpg)
# ![image1_H.jpg](attachment:image1_H.jpg)
# ![image2_H.jpg](attachment:image2_H.jpg)
# ![image3_H.jpg](attachment:image3_H.jpg)

# %%
img = cv2.imread('images/image.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
corners = cv2.goodFeaturesToTrack(gray,25,0.01,10)
corners = np.int0(corners)
for i in corners:
    x,y = i.ravel()
    cv2.circle(img,(x,y),3,255,-1)

cv2.imwrite('images/image_S.jpg', img)
# Out:
# True

# %% [markdown]
# ![image_S.jpg](attachment:image_S.jpg)
# ![image1_S.jpg](attachment:image1_S.jpg)
# ![image2_S.jpg](attachment:image2_S.jpg)
# ![image3_S.jpg](attachment:image3_S.jpg)

# %%
img = cv2.imread('images/image.jpg')
num_rows, num_cols = img.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((num_cols/2,
num_rows/2), 210, 0.8)
img_rotation = cv2.warpAffine(img, rotation_matrix,
(num_cols, num_rows))
cv2.imwrite('images/image_b.jpg', img_rotation)

rotation_matrix = cv2.getRotationMatrix2D((num_cols/2,
num_rows/2), 270, 0.75)
img_e = cv2.warpAffine(img, rotation_matrix,
(num_cols, num_rows))
res_e = cv2.resize(img_e, dsize=(942, 540), interpolation=cv2.INTER_CUBIC)
cv2.imwrite('images/image_e.jpg', res_e)
# Out:
# True

# %%
res = cv2.resize(img, dsize=(628*2, 360*2), interpolation=cv2.INTER_CUBIC)
cv2.imwrite('images/image_c.jpg', res)
# Out:
# True

# %% [markdown]
# ![image_a.jpg](attachment:image_a.jpg)
# ![image_b.jpg](attachment:image_b.jpg)
# ![image_c.jpg](attachment:image_c.jpg)
# ![image_d.jpg](attachment:image_d.jpg)
# ![image_e.jpg](attachment:image_e.jpg)

# %%
img1 = cv2.imread(r'images/shablon.jpg', 0) # queryImage
img2 = cv2.imread(r'images/image_a.jpg', 0) # trainImage
sift = cv2.xfeatures2d.SIFT_create() # Initiate SIFT detector
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
bf = cv2.BFMatcher() # BFMatcher with default params
matches = bf.knnMatch(des1,des2, k=2)
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
# cv2.drawMatchesKnn expects list of lists as matches.
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2, matches1to2=good,
outImg=None, flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f6a80a644a8>, None)

# %%
img1 = cv2.imread(r'images/shablon.jpg', 0) # queryImage
img2 = cv2.imread(r'images/image_b.jpg', 0) # trainImage
sift = cv2.xfeatures2d.SIFT_create() # Initiate SIFT detector
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
bf = cv2.BFMatcher() # BFMatcher with default params
matches = bf.knnMatch(des1,des2, k=2)
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
# cv2.drawMatchesKnn expects list of lists as matches.
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2, matches1to2=good,
outImg=None, flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f6a80a43940>, None)

# %%
img1 = cv2.imread(r'images/shablon.jpg', 0) # queryImage
img2 = cv2.imread(r'images/image_c.jpg', 0) # trainImage
sift = cv2.xfeatures2d.SIFT_create() # Initiate SIFT detector
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
bf = cv2.BFMatcher() # BFMatcher with default params
matches = bf.knnMatch(des1,des2, k=2)
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
# cv2.drawMatchesKnn expects list of lists as matches.
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2, matches1to2=good,
outImg=None, flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f6a809b4dd8>, None)

# %%
img1 = cv2.imread(r'images/shablon.jpg', 0) # queryImage
img2 = cv2.imread(r'images/image_d.jpg', 0) # trainImage
sift = cv2.xfeatures2d.SIFT_create() # Initiate SIFT detector
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
bf = cv2.BFMatcher() # BFMatcher with default params
matches = bf.knnMatch(des1,des2, k=2)
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
# cv2.drawMatchesKnn expects list of lists as matches.
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2, matches1to2=good,
outImg=None, flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f6a8099bc50>, None)

# %%
img1 = cv2.imread(r'images/shablon.jpg', 0) # queryImage
img2 = cv2.imread(r'images/image_e.jpg', 0) # trainImage
sift = cv2.xfeatures2d.SIFT_create() # Initiate SIFT detector
# find the keypoints and descriptors with SIFT
kp1, des1 = sift.detectAndCompute(img1,None)
kp2, des2 = sift.detectAndCompute(img2,None)
bf = cv2.BFMatcher() # BFMatcher with default params
matches = bf.knnMatch(des1,des2, k=2)
# Apply ratio test
good = []
for m,n in matches:
    if m.distance < 0.75*n.distance:
        good.append([m])
# cv2.drawMatchesKnn expects list of lists as matches.
img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2, matches1to2=good,
outImg=None, flags=2)
plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7f6a80bd0e48>, None)
